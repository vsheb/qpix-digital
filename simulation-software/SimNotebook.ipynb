# %%
from QpixAsic import *
import random
import math

# This is a single trial array

# Seed the RNG
random.seed(None)

# Debug status
debugLevel = 5 #5 - debug

# Create an array of QPixAsics
nRows = 2
nCols = 2
nPixs = 16

# Nominal frequency and associated spread (as 1-sigma in percent)
fNominal  = 50e6
pctSpread = 0.05

# Time interval between DAQ-node timestamps
deltaT = 1.0
# Ticks in nominal oscillator between DAQ-node timestamps
deltaTick = int(math.floor(deltaT * fNominal))
# Small time interval used for stepping simulation almost up to current
timeEpsilon = 1e-6

# How long to run the simulation
timeEnd = 2.5

# %%
# Create the array and populate all positions
asicMatrix = [[None for i in range(nCols)] for j in range(nRows)] 

for i in range(0,nRows):
  for j in range(0,nCols):
    # Create the random frequency here
    fThisAsic = random.gauss(fNominal,fNominal*pctSpread)
    # Create an ASIC at this position
    asicMatrix[i][j] = QPixAsic(fThisAsic, nPixs, row = i, col = j)
    ## Debug info
    if debugLevel >= 5:
      print("Created ASIC at row "+str(i)+" col "+str(j)+" with frequency "+str(fThisAsic))

#if debugLevel >= 5:
#  print(asicMatrix)
# Out:
# Created ASIC at row 0 col 0 with frequency 47218745.58299393
# Created ASIC at row 0 col 1 with frequency 50444346.27475346
# Created ASIC at row 1 col 0 with frequency 47848291.09373051
# Created ASIC at row 1 col 1 with frequency 53210278.14371917

# %%
# Create the connections between all ASICs
for i in range(0,nRows):
  for j in range(0,nCols):
    # 0 - North
    # 1 - East
    # 2 - South
    # 3 - West
    if i > 0:
      asicMatrix[i][j].connections[0] = asicMatrix[i-1][j]
    if i < nRows-1:
      asicMatrix[i][j].connections[2] = asicMatrix[i+1][j]
    if j > 0:
      asicMatrix[i][j].connections[3] = asicMatrix[i][j-1]
    if j < nCols-1:
      asicMatrix[i][j].connections[1] = asicMatrix[i][j+1]

# %%
# Create a dummy DAQ node and connect it up to our target
daqNode = QPixAsic(fNominal, 0, isDaqNode = True)
asicMatrix[0][0].connections[3] = daqNode

# %%
# Print count of connections vs. position
if debugLevel >= 5:
  print("Connection count per ASIC:")
  for i in range(0,nRows):
    for j in range(0,nCols):
      print( str(asicMatrix[i][j].CountConnections())+" ", end = '')
    print("")
# Out:
# Connection count per ASIC:
# 3 2
# 2 2

# %%
# Print north connections vs. position
if debugLevel >= 5:
  for d in range(0,len(DIRECTIONS)):
    dir = DIRECTIONS[d]
    print("Connections to the "+dir+" per ASIC:")
    for i in range(0,nRows):
      for j in range(0,nCols):
        print( str(asicMatrix[i][j].HasConnection(d))+" ", end = '')
      print("")
# Out:
# Connections to the North per ASIC:
# 0 0
# 1 1
# Connections to the East per ASIC:
# 1 0
# 1 0
# Connections to the South per ASIC:
# 1 1
# 0 0
# Connections to the West per ASIC:
# 1 1
# 0 1

# %%
# Start time now
timeNow = 0
tickNow = 0
stepNum = 0

# Create an empty processing queue
procQueue = ProcQueue()

# %%
timeNow += deltaT
tickNow += deltaTick

# Maximum queue depths
maxConnQueueDepths = [[[0 for i in range(nCols)] for j in range(nRows)] for k in range(4)]
maxSelfQueueDepths = [[0 for i in range(nCols)] for j in range(nRows)]

while(timeNow < timeEnd):

  # Make sure there's nothing to do right now
  # Now iterate through ASICs and keep doing processing on them until
  # they're caught up to the latest time.
  for i in range(0,nRows):
    for j in range(0,nCols):
      newProcessItems = asicMatrix[i][j].Process(timeNow - timeEpsilon)
      if len(newProcessItems) > 0:
        print("WARNING: ASIC ("+str(i)+","+str(j)+") had things left to do at next major time step")

        # Print states if they were updated
        if debugLevel >= 5:
          asicMatrix[i][j].PrintStatus()
          print("ASIC ("+str(i)+","+str(j)+") state updated in step "+str(stepNum)+", time "+str(asicMatrix[i][j].absTimeNow)+":")
          # for i in range(0,nRows):
          #   for j in range(0,nCols):
          #     print( str(asicMatrix[i][j].stateNum)+" ", end = '')
          #   print("")

  # Add a first timestamp at 1 second
  timestamp = PixelHit(tickNow, [], None, None)                
    
  procQueue.AddQueueItem(asicMatrix[0][0], 3, timestamp, timeNow)

  while(procQueue.Length() > 0):
    #  print("Before step "+str(stepNum)+" list length is: "+str(procQueue.Length()))
    nextItem = procQueue.PopQueue()
    print("Next item is: ",end='')
    print(nextItem)
    nextAsic = nextItem[0]
    newQueueItems = nextAsic.ReceiveData(nextItem)
    for item in newQueueItems:
      procQueue.queue.append(item)
      procQueue.SortQueue()
      print("After step "+str(stepNum)+" list length is: "+str(procQueue.Length()))

    # Check the current queue depths
    for i in range(0,nRows):
      for j in range(0,nCols):
        # Local queue depth
        localDepthA = len(asicMatrix[i][j].queues[0])
        localDepthB = len(asicMatrix[i][j].queues[1])
        localMax    = localDepthA if localDepthA > localDepthB else localDepthB
        curMaxDepth = maxSelfQueueDepths[i][j]
        if (localMax > curMaxDepth):
          maxSelfQueueDepths[i][j] = localMax
          # Do the same for all the neighbor queues
          for d in range(0,4):
            curMaxDepth = maxConnQueueDepths[d][i][j]
            localMax    = len(asicMatrix[i][j].connQueues[d])
            if localMax > curMaxDepth:
              maxConnQueueDepths[d][i][j] = curMaxDepth

    # Print states at every step
    if debugLevel >= 5:
      asicMatrix[i][j].PrintStatus()
      print("ASIC state status after step "+str(stepNum)+", time "+str(nextItem[3])+":")
      for i in range(0,nRows):
        for j in range(0,nCols):
          print( str(asicMatrix[i][j].stateNum)+" ", end = '')
        print("")

    # Now iterate through ASICs and keep doing processing on them until
    # they're caught up to the latest time.
    somethingToDo = True
    while somethingToDo and procQueue.Length() > 0:
      nextTime = procQueue.queue[0][3]
      somethingToDo = False
      for i in range(0,nRows):
        for j in range(0,nCols):
          if nextTime > asicMatrix[i][j].absTimeNow:
            nothingToDo = False
            newProcessItems = asicMatrix[i][j].Process(nextTime)
            for item in newProcessItems:
              procQueue.queue.append(item)
            procQueue.SortQueue()

            # Print states if they were updated
            if debugLevel >= 5:
              asicMatrix[i][j].PrintStatus()
              print("ASIC ("+str(i)+","+str(j)+") state updated in step "+str(stepNum)+", time "+str(asicMatrix[i][j].absTimeNow)+":")
              for i in range(0,nRows):
                for j in range(0,nCols):
                  print( str(asicMatrix[i][j].stateNum)+" ", end = '')
                print("")

    stepNum += 1

  timeNow += deltaT
  tickNow += deltaTick
# Out:
# Next item is: (<QpixAsic.QPixAsic object at 0x000001A0F89AD2D0>, 3, <QpixAsic.PixelHit object at 0x000001A0F8941E70>, 1.0)
# After step 0 list length is: 1
# After step 0 list length is: 2
#  ASIC (1,1)  STATE 0 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 0.999999
# ASIC state status after step 0, time 1.0:
# 1 0
# 0 0
#  ASIC (0,1)  STATE 0 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.000005590999861
# ASIC (0,1) state updated in step 0, time 1.000005590999861:
# 1 0
# 0 0
#  ASIC (1,0)  STATE 0 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.000005590999861
# ASIC (1,0) state updated in step 0, time 1.000005590999861:
# 1 0
# 0 0
#  ASIC (1,1)  STATE 0 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.000005590999861
# ASIC (1,1) state updated in step 0, time 1.000005590999861:
# 1 0
# 0 0
# Next item is: (<QpixAsic.QPixAsic object at 0x000001A0F88F4220>, 3, <QpixAsic.PixelHit object at 0x000001A0F8941E70>, 1.000005590999861)
# After step 1 list length is: 2
#  ASIC (1,1)  STATE 0 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.000005590999861
# ASIC state status after step 1, time 1.000005590999861:
# 1 1
# 0 0
# Next item is: (<QpixAsic.QPixAsic object at 0x000001A0F89ACD00>, 0, <QpixAsic.PixelHit object at 0x000001A0F8941E70>, 1.000005590999861)
# After step 2 list length is: 2
#  ASIC (1,1)  STATE 0 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.000005590999861
# ASIC state status after step 2, time 1.000005590999861:
# 1 1
# 1 0
#  ASIC (0,0)  STATE 1 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000111819997222
# ASIC (0,0) state updated in step 2, time 1.0000111819997222:
# 1 1
# 1 0
#  ASIC (1,1)  STATE 0 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000108244902222
# ASIC (1,1) state updated in step 2, time 1.0000108244902222:
# 1 1
# 1 0
# Next item is: (<QpixAsic.QPixAsic object at 0x000001A0F89AD990>, 0, <QpixAsic.PixelHit object at 0x000001A0F8941E70>, 1.0000108244902222)
# After step 3 list length is: 3
#  ASIC (1,1)  STATE 1 N_LOCAL(A,B) 1,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000157859376946
# ASIC state status after step 3, time 1.0000108244902222:
# 1 1
# 1 1
#  ASIC (0,1)  STATE 1 N_LOCAL(A,B) 1,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000160579805832
# ASIC (0,1) state updated in step 3, time 1.0000160579805832:
# 1 1
# 1 1
# Next item is: (<QpixAsic.QPixAsic object at 0x000001A0F89AD990>, 3, <QpixAsic.PixelHit object at 0x000001A0F8941E70>, 1.0000111084382892)
#  ASIC (1,1)  STATE 1 N_LOCAL(A,B) 1,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000157859376946
# ASIC state status after step 4, time 1.0000111084382892:
# 1 1
# 1 1
#  ASIC (1,0)  STATE 1 N_LOCAL(A,B) 1,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000166258767174
# ASIC (1,0) state updated in step 4, time 1.0000166258767174:
# 1 1
# 1 1
# Next item is: (<QpixAsic.QPixAsic object at 0x000001A0F89AEB00>, 1, <QpixAsic.PixelHit object at 0x000001A0F8943DC0>, 1.0000111819997222)
#  ASIC (1,1)  STATE 1 N_LOCAL(A,B) 1,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000157859376946
# ASIC state status after step 5, time 1.0000111819997222:
# 1 1
# 1 1
#  ASIC (0,0)  STATE 2 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000111819997222
# ASIC (0,0) state updated in step 5, time 1.0000111819997222:
# 2 1
# 1 1
# Next item is: (<QpixAsic.QPixAsic object at 0x000001A0F89ACD00>, 1, <QpixAsic.PixelHit object at 0x000001A0F8941E70>, 1.0000157859376946)
#  ASIC (1,1)  STATE 1 N_LOCAL(A,B) 1,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000157859376946
# ASIC state status after step 6, time 1.0000157859376946:
# 2 1
# 1 1
#  ASIC (0,0)  STATE 2 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000160579805832
# ASIC (0,0) state updated in step 6, time 1.0000160579805832:
# 2 1
# 1 1
#  ASIC (1,1)  STATE 1 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.000020747385167
# ASIC (1,1) state updated in step 6, time 1.000020747385167:
# 2 1
# 1 1
# Next item is: (<QpixAsic.QPixAsic object at 0x000001A0F89AD2D0>, 1, <QpixAsic.PixelHit object at 0x000001A0F85163E0>, 1.0000160579805832)
#  ASIC (1,1)  STATE 1 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.000020747385167
# ASIC state status after step 7, time 1.0000160579805832:
# 2 1
# 1 1
#  ASIC (0,0)  STATE 2 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000216489804443
# ASIC (0,0) state updated in step 7, time 1.0000216489804443:
# 2 1
# 1 1
# Next item is: (<QpixAsic.QPixAsic object at 0x000001A0F89AD2D0>, 2, <QpixAsic.PixelHit object at 0x000001A0F898C9A0>, 1.0000166258767174)
#  ASIC (1,1)  STATE 1 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.000020747385167
# ASIC state status after step 8, time 1.0000166258767174:
# 2 1
# 1 1
#  ASIC (0,1)  STATE 1 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000212914709443
# ASIC (0,1) state updated in step 8, time 1.0000212914709443:
# 2 1
# 1 1
#  ASIC (1,0)  STATE 1 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000221433151455
# ASIC (1,0) state updated in step 8, time 1.0000221433151455:
# 2 1
# 1 1
# Next item is: (<QpixAsic.QPixAsic object at 0x000001A0F88F4220>, 2, <QpixAsic.PixelHit object at 0x000001A0F898FA60>, 1.000020747385167)
#  ASIC (1,1)  STATE 1 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.000020747385167
# ASIC state status after step 9, time 1.000020747385167:
# 2 1
# 1 1
#  ASIC (1,1)  STATE 2 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.000020747385167
# ASIC (1,1) state updated in step 9, time 1.000020747385167:
# 2 1
# 1 2
# Next item is: (<QpixAsic.QPixAsic object at 0x000001A0F89AD2D0>, 1, <QpixAsic.PixelHit object at 0x000001A0F88F6FB0>, 1.0000212914709443)
#  ASIC (1,1)  STATE 2 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.000020747385167
# ASIC state status after step 10, time 1.0000212914709443:
# 2 1
# 1 2
#  ASIC (0,1)  STATE 2 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,1,0, t = 1.0000212914709443
# ASIC (0,1) state updated in step 10, time 1.0000212914709443:
# 2 2
# 1 2
#  ASIC (1,1)  STATE 2 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000216489804443
# ASIC (1,1) state updated in step 10, time 1.0000216489804443:
# 2 2
# 1 2
# Next item is: (<QpixAsic.QPixAsic object at 0x000001A0F89AEB00>, 1, <QpixAsic.PixelHit object at 0x000001A0F85163E0>, 1.0000216489804443)
#  ASIC (1,1)  STATE 2 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000216489804443
# ASIC state status after step 11, time 1.0000216489804443:
# 2 2
# 1 2
#  ASIC (0,0)  STATE 2 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,1,0, t = 1.0000272399803054
# ASIC (0,0) state updated in step 11, time 1.0000272399803054:
# 2 2
# 1 2
#  ASIC (1,1)  STATE 2 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000221433151455
# ASIC (1,1) state updated in step 11, time 1.0000221433151455:
# 2 2
# 1 2
# Next item is: (<QpixAsic.QPixAsic object at 0x000001A0F89AD2D0>, 2, <QpixAsic.PixelHit object at 0x000001A0F898FCD0>, 1.0000221433151455)
#  ASIC (1,1)  STATE 2 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000221433151455
# ASIC state status after step 12, time 1.0000221433151455:
# 2 2
# 1 2
#  ASIC (0,1)  STATE 2 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000265249613054
# ASIC (0,1) state updated in step 12, time 1.0000265249613054:
# 2 2
# 1 2
#  ASIC (1,0)  STATE 2 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000221433151455
# ASIC (1,0) state updated in step 12, time 1.0000221433151455:
# 2 2
# 2 2
#  ASIC (1,1)  STATE 2 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000272399803054
# ASIC (1,1) state updated in step 12, time 1.0000272399803054:
# 2 2
# 2 2
# Next item is: (<QpixAsic.QPixAsic object at 0x000001A0F89AD2D0>, 1, <QpixAsic.PixelHit object at 0x000001A0F898FA60>, 1.0000265249613054)
#  ASIC (1,1)  STATE 2 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000272399803054
# ASIC state status after step 13, time 1.0000265249613054:
# 2 2
# 2 2
#  ASIC (0,1)  STATE 2 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000272399803054
# ASIC (0,1) state updated in step 13, time 1.0000272399803054:
# 2 2
# 2 2
#  ASIC (1,0)  STATE 2 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000272399803054
# ASIC (1,0) state updated in step 13, time 1.0000272399803054:
# 2 2
# 2 2
# Next item is: (<QpixAsic.QPixAsic object at 0x000001A0F89AEB00>, 1, <QpixAsic.PixelHit object at 0x000001A0F88F6FB0>, 1.0000272399803054)
#  ASIC (1,1)  STATE 2 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.0000272399803054
# ASIC state status after step 14, time 1.0000272399803054:
# 2 2
# 2 2
# WARNING: ASIC (0,0) had things left to do at next major time step
#  ASIC (0,0)  STATE 2 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,2,0, t = 1.0000328309801665
# ASIC (0,0) state updated in step 15, time 1.0000328309801665:
# Next item is: (<QpixAsic.QPixAsic object at 0x000001A0F89AD2D0>, 3, <QpixAsic.PixelHit object at 0x000001A0F898E740>, 2.0)
#  ASIC (1,1)  STATE 0 N_LOCAL(A,B) 0,0 N_REMOTE(N,E,S,W) 0,0,0,0, t = 1.999999
# ASIC state status after step 15, time 2.0:
# 2 0
# 0 0
